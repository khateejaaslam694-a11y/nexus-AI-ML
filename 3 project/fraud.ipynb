# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 1. Load the Dataset
# IMPORTANT: Replace 'YOUR_FRAUD_DATASET_NAME.csv' with your actual file name
try:
    df = pd.read_csv('creditcard.csv')
    print("--- Data Loaded Successfully ---")
    print(df.head())
    print("\n")
except FileNotFoundError:
    print("Error: Please replace 'YOUR_FRAUD_DATASET_NAME.csv' with your file name.")
    # Exit or provide placeholder logic if the file is not found
    # For now, we continue with placeholder column names

# 2. Check for Class Imbalance (Matching the distribution plot idea)
# IMPORTANT: Replace 'Class' with the name of your fraud/non-fraud target column
TARGET_COLUMN = 'Class'

if TARGET_COLUMN in df.columns:
    print(f"--- Distribution of the Target Column: '{TARGET_COLUMN}' ---")
    print(df[TARGET_COLUMN].value_counts())
    
    # Plot the class distribution (Crucial for fraud analysis)
    plt.figure(figsize=(7, 5))
    sns.countplot(x=TARGET_COLUMN, data=df, palette='viridis')
    plt.title('Class Imbalance Check (Fraud vs. Non-Fraud)')
    plt.xlabel('Class (0: Non-Fraud, 1: Fraud)')
    plt.ylabel('Number of Transactions')
    plt.show()
    # 

# 3. Feature Scaling and Data Preparation
    
    # Separate features (X) and target (y)
    # Exclude non-numerical or identifying columns like 'Time', 'ID', etc.
    X = df.drop(columns=[TARGET_COLUMN, 'Time', 'ID'], errors='ignore').values
    y = df[TARGET_COLUMN].values
    
    print("\n--- Feature Scaling ---")
    # Scale features, which is critical for distance-based algorithms like K-Means or Neural Networks
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    print("Data scaled and ready for model training.")

# 4. Model Training (Placeholder for Supervised Classification)
    # The common next step is to split the data and train a classifier (e.g., Logistic Regression, Random Forest)
    # X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42, stratify=y)

    # print(f"\nTraining set size: {X_train.shape}")
    # print(f"Testing set size: {X_test.shape}")
else:
    print("Cannot proceed with analysis. Target column not found.")
# Out:
# --- Data Loaded Successfully ---
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...
